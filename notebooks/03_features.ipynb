# %% [markdown]
# # 特徵工程實驗
#
# - lag / rolling / 成長率 / 季節性 / 市場結構
# - 外部變數併入（注意發布時滯）
# - 特徵相關性與共線性檢查

# %%
import sys
sys.path.append('..')

import pandas as pd
from src import config

cfg = config.load('params')
