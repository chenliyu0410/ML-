# %% [markdown]
# # 探索性分析
#
# - 資料涵蓋期間、筆數、國家數、稅號數
# - 缺失值：是「沒進口」還是「沒資料」？兩者處理方式不同
# - 離群值：單筆超大金額先查原因，不要直接刪
# - 資訊保護遮罩：關務署對可能揭露個別廠商的資料做保護處理，檢查異常空值

# %%
import sys
sys.path.append('..')

import pandas as pd
from src import config

cfg = config.load('params')
