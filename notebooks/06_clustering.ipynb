# %% [markdown]
# # 國家 × 品項分群
#
# - 特徵矩陣：單價水位、單價 CAGR、進口量 CAGR、市占、波動度、集中度
# - 標準化（K-Means 靠距離，必做）→ PCA
# - 手肘法定 K + 輪廓係數驗證
# - 象限圖 → 高單價高成長採購建議名單

# %%
import sys
sys.path.append('..')

import pandas as pd
from src import config

cfg = config.load('params')
