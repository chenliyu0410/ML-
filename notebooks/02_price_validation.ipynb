# %% [markdown]
# # ★ 精緻化假設驗證
#
# - 名目單價趨勢（USD/kg）
# - 以 IPI / CPI 平減 → 實質單價
# - USD vs TWD 計價交叉驗證，剝離匯率效果
# - 對照玉米、雞肉、SCFI 運價，排除原物料與運費
# - 檢查 2017 / 2022 HS 改版是否造成斷點
# - 對照組：一般食品類進口單價，比較相對漲幅
# - → 結論：精緻化假設成立或不成立

# %%
import sys
sys.path.append('..')

import pandas as pd
from src import config

cfg = config.load('params')
