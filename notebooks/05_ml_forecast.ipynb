# %% [markdown]
# # LightGBM 全域模型
#
# - 所有國家 × 品項疊在一起訓練單一模型
# - TimeSeriesSplit 滾動回測
# - 超參數調校
# - holdout 最終評估（只評一次）
# - 特徵重要度 / SHAP
# - → 務必報告相對 baseline 的改善率

# %%
import sys
sys.path.append('..')

import pandas as pd
from src import config

cfg = config.load('params')
