# %% [markdown]
# # Baseline — 一定要做
#
# - Naive：預測值 = 上期值
# - Seasonal Naive：預測值 = 去年同月值
# - SARIMA / Prophet
# - → 這裡的分數就是後面所有模型必須超越的門檻

# %%
import sys
sys.path.append('..')

import pandas as pd
from src import config

cfg = config.load('params')
